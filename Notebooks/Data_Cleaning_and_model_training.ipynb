# %% [markdown]
# ***Cleaning of data***

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sklearn 
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np

# %%
df = pd.read_csv(fr"../synthetic_ecommerce_data.csv")

# %%
df.head()
# Out:
#                             customer_id  gender  age           country  \
# 0  71974402-3ecd-4cb6-90cb-84805ac45d6a    Male   19             Sudan
# 1  7f656f70-7a89-4a4e-9bae-9d1d403f70a7    Male   55              Niue
# 2  0bb2052d-7d53-4bbb-adc5-0ceb202e3de0    Male   50  Papua New Guinea
# 3  c636d181-1763-4cbc-8efc-afe08c923639  Female   32           Ukraine
# 4  e8dbc1eb-d0ac-4c39-b032-7f1a149e13d6  Female   39           Belarus
#
#    pages_visited  session_time  purchased product_clicked product_category  \
# 0              9          8.48          0           seven      Electronics
# 1             14          2.41          0         between         Clothing
# 2             20          2.26          0        anything           Beauty
# 3             15         18.29          0            blue         Clothing
# 4              9          5.93          1             eat      Electronics
#
#    price
# 0   0.00
# 1   0.00
# 2   0.00
# 3   0.00
# 4  50.91

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       2000 non-null   object
#  1   gender            2000 non-null   object
#  2   age               2000 non-null   int64
#  3   country           2000 non-null   object
#  4   pages_visited     2000 non-null   int64
#  5   session_time      2000 non-null   float64
#  6   purchased         2000 non-null   int64
#  7   product_clicked   2000 non-null   object
#  8   product_category  2000 non-null   object
#  9   price             2000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 156.4+ KB

# %%
df
# Out:
#                                customer_id  gender  age            country  \
# 0     71974402-3ecd-4cb6-90cb-84805ac45d6a    Male   19              Sudan
# 1     7f656f70-7a89-4a4e-9bae-9d1d403f70a7    Male   55               Niue
# 2     0bb2052d-7d53-4bbb-adc5-0ceb202e3de0    Male   50   Papua New Guinea
# 3     c636d181-1763-4cbc-8efc-afe08c923639  Female   32            Ukraine
# 4     e8dbc1eb-d0ac-4c39-b032-7f1a149e13d6  Female   39            Belarus
# ...                                    ...     ...  ...                ...
# 1995  b884d741-1f87-4619-9367-8b841131023c  Female   38            Croatia
# 1996  be6b0907-f556-49ed-9356-614c00a617eb    Male   38  Equatorial Guinea
# 1997  9e5f1d24-576c-4afa-ae08-3b28e368430a    Male   38              Japan
# 1998  afad0595-9124-4095-8905-dc1e163c5b55  Female   48            Namibia
# 1999  91213eee-cd84-4981-9cd8-b064ba572821  Female   46            Mayotte
#
#       pages_visited  session_time  purchased product_clicked product_category  \
# 0                 9          8.48          0           seven      Electronics
# 1                14          2.41          0         between         Clothing
# 2                20          2.26          0        anything           Beauty
# 3                15         18.29          0            blue         Clothing
# 4                 9          5.93          1             eat      Electronics
# ...             ...           ...        ...             ...              ...
# 1995             17         14.95          1            ball           Beauty
# 1996              6          6.97          1             act         Clothing
# 1997             17         29.46          1            yeah            Books
# 1998             10         12.07          1           prove            Books
# 1999             10         13.62          1       education             Home
#
#        price
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4      50.91
# ...      ...
# 1995  109.09
# 1996  426.92
# 1997  118.22
# 1998  364.72
# 1999    7.81
#
# [2000 rows x 10 columns]

# %%
df.drop(columns = 'customer_id',inplace = True)

# %%
df
# Out:
#       gender  age            country  pages_visited  session_time  purchased  \
# 0       Male   19              Sudan              9          8.48          0
# 1       Male   55               Niue             14          2.41          0
# 2       Male   50   Papua New Guinea             20          2.26          0
# 3     Female   32            Ukraine             15         18.29          0
# 4     Female   39            Belarus              9          5.93          1
# ...      ...  ...                ...            ...           ...        ...
# 1995  Female   38            Croatia             17         14.95          1
# 1996    Male   38  Equatorial Guinea              6          6.97          1
# 1997    Male   38              Japan             17         29.46          1
# 1998  Female   48            Namibia             10         12.07          1
# 1999  Female   46            Mayotte             10         13.62          1
#
#      product_clicked product_category   price
# 0              seven      Electronics    0.00
# 1            between         Clothing    0.00
# 2           anything           Beauty    0.00
# 3               blue         Clothing    0.00
# 4                eat      Electronics   50.91
# ...              ...              ...     ...
# 1995            ball           Beauty  109.09
# 1996             act         Clothing  426.92
# 1997            yeah            Books  118.22
# 1998           prove            Books  364.72
# 1999       education             Home    7.81
#
# [2000 rows x 9 columns]

# %%
df['country'].value_counts()
# Out:
# country
# Congo                        19
# Wallis and Futuna            16
# Malawi                       16
# Fiji                         15
# Austria                      15
#                              ..
# Netherlands Antilles          3
# Cook Islands                  3
# Bouvet Island (Bouvetoya)     2
# Estonia                       2
# Luxembourg                    2
# Name: count, Length: 243, dtype: int64

# %%
df.drop(columns= 'product_clicked', inplace = True)

# %%
df
# Out:
#       gender  age            country  pages_visited  session_time  purchased  \
# 0       Male   19              Sudan              9          8.48          0
# 1       Male   55               Niue             14          2.41          0
# 2       Male   50   Papua New Guinea             20          2.26          0
# 3     Female   32            Ukraine             15         18.29          0
# 4     Female   39            Belarus              9          5.93          1
# ...      ...  ...                ...            ...           ...        ...
# 1995  Female   38            Croatia             17         14.95          1
# 1996    Male   38  Equatorial Guinea              6          6.97          1
# 1997    Male   38              Japan             17         29.46          1
# 1998  Female   48            Namibia             10         12.07          1
# 1999  Female   46            Mayotte             10         13.62          1
#
#      product_category   price
# 0         Electronics    0.00
# 1            Clothing    0.00
# 2              Beauty    0.00
# 3            Clothing    0.00
# 4         Electronics   50.91
# ...               ...     ...
# 1995           Beauty  109.09
# 1996         Clothing  426.92
# 1997            Books  118.22
# 1998            Books  364.72
# 1999             Home    7.81
#
# [2000 rows x 8 columns]

# %%
len(df['country'].unique())   # Number of unique countries
# Out:
# 243

# %% [markdown]
# This means that we would need to convert these words (countries) into numeric data using encoders

# %%
df
# Out:
#       gender  age            country  pages_visited  session_time  purchased  \
# 0       Male   19              Sudan              9          8.48          0
# 1       Male   55               Niue             14          2.41          0
# 2       Male   50   Papua New Guinea             20          2.26          0
# 3     Female   32            Ukraine             15         18.29          0
# 4     Female   39            Belarus              9          5.93          1
# ...      ...  ...                ...            ...           ...        ...
# 1995  Female   38            Croatia             17         14.95          1
# 1996    Male   38  Equatorial Guinea              6          6.97          1
# 1997    Male   38              Japan             17         29.46          1
# 1998  Female   48            Namibia             10         12.07          1
# 1999  Female   46            Mayotte             10         13.62          1
#
#      product_category   price
# 0         Electronics    0.00
# 1            Clothing    0.00
# 2              Beauty    0.00
# 3            Clothing    0.00
# 4         Electronics   50.91
# ...               ...     ...
# 1995           Beauty  109.09
# 1996         Clothing  426.92
# 1997            Books  118.22
# 1998            Books  364.72
# 1999             Home    7.81
#
# [2000 rows x 8 columns]

# %%
categorical_features = ['gender', 'country', 'product_category']
numeric_features = ['age', 'pages_visited', 'session_time', 'price']
target = 'purchased'

# %%
df_cleaned=df

# %%
X = df_cleaned.drop(columns=[target])
y = df_cleaned[target]

# %%
df_cleaned
# Out:
#       gender  age            country  pages_visited  session_time  purchased  \
# 0       Male   19              Sudan              9          8.48          0
# 1       Male   55               Niue             14          2.41          0
# 2       Male   50   Papua New Guinea             20          2.26          0
# 3     Female   32            Ukraine             15         18.29          0
# 4     Female   39            Belarus              9          5.93          1
# ...      ...  ...                ...            ...           ...        ...
# 1995  Female   38            Croatia             17         14.95          1
# 1996    Male   38  Equatorial Guinea              6          6.97          1
# 1997    Male   38              Japan             17         29.46          1
# 1998  Female   48            Namibia             10         12.07          1
# 1999  Female   46            Mayotte             10         13.62          1
#
#      product_category   price
# 0         Electronics    0.00
# 1            Clothing    0.00
# 2              Beauty    0.00
# 3            Clothing    0.00
# 4         Electronics   50.91
# ...               ...     ...
# 1995           Beauty  109.09
# 1996         Clothing  426.92
# 1997            Books  118.22
# 1998            Books  364.72
# 1999             Home    7.81
#
# [2000 rows x 8 columns]

# %%
category_encoded = pd.DataFrame({
    'product_category': df_cleaned['product_category'],
    'country': df_cleaned['country'],
    'gender': df_cleaned['gender']
})

# %%
category_encoded
# Out:
#      product_category            country  gender
# 0         Electronics              Sudan    Male
# 1            Clothing               Niue    Male
# 2              Beauty   Papua New Guinea    Male
# 3            Clothing            Ukraine  Female
# 4         Electronics            Belarus  Female
# ...               ...                ...     ...
# 1995           Beauty            Croatia  Female
# 1996         Clothing  Equatorial Guinea    Male
# 1997            Books              Japan    Male
# 1998            Books            Namibia  Female
# 1999             Home            Mayotte  Female
#
# [2000 rows x 3 columns]

# %%
label_encoder = LabelEncoder()
X['product_category'] = label_encoder.fit_transform(category_encoded['product_category'])
X['country'] = label_encoder.fit_transform(category_encoded['country'])
X['gender'] = label_encoder.fit_transform(category_encoded['gender'])

# %%
X
# Out:
#       gender  age  country  pages_visited  session_time   price  \
# 0          1   19      205              9          8.48    0.00
# 1          1   55      158             14          2.41    0.00
# 2          1   50      168             20          2.26    0.00
# 3          0   32      227             15         18.29    0.00
# 4          0   39       19              9          5.93   50.91
# ...      ...  ...      ...            ...           ...     ...
# 1995       0   38       53             17         14.95  109.09
# 1996       1   38       64              6          6.97  426.92
# 1997       1   38      108             17         29.46  118.22
# 1998       0   48      148             10         12.07  364.72
# 1999       0   46      137             10         13.62    7.81
#
#       category_encoded  product_category
# 0                    3                 3
# 1                    2                 2
# 2                    0                 0
# 3                    2                 2
# 4                    3                 3
# ...                ...               ...
# 1995                 0                 0
# 1996                 2                 2
# 1997                 1                 1
# 1998                 1                 1
# 1999                 4                 4
#
# [2000 rows x 8 columns]

# %%
X.drop(columns = "category_encoded", inplace = True)

# %%
X
# Out:
#       gender  age  country  pages_visited  session_time   price  \
# 0          1   19      205              9          8.48    0.00
# 1          1   55      158             14          2.41    0.00
# 2          1   50      168             20          2.26    0.00
# 3          0   32      227             15         18.29    0.00
# 4          0   39       19              9          5.93   50.91
# ...      ...  ...      ...            ...           ...     ...
# 1995       0   38       53             17         14.95  109.09
# 1996       1   38       64              6          6.97  426.92
# 1997       1   38      108             17         29.46  118.22
# 1998       0   48      148             10         12.07  364.72
# 1999       0   46      137             10         13.62    7.81
#
#       product_category
# 0                    3
# 1                    2
# 2                    0
# 3                    2
# 4                    3
# ...                ...
# 1995                 0
# 1996                 2
# 1997                 1
# 1998                 1
# 1999                 4
#
# [2000 rows x 7 columns]

# %% [markdown]
# Data above is now numerical.

# %%
X_correlation = X.corr()

# %%
X_correlation
# Out:
#                     gender       age   country  pages_visited  session_time  \
# gender            1.000000 -0.030027  0.020337       0.007093     -0.009346
# age              -0.030027  1.000000 -0.017014      -0.011346      0.013134
# country           0.020337 -0.017014  1.000000       0.026038      0.031694
# pages_visited     0.007093 -0.011346  0.026038       1.000000      0.013015
# session_time     -0.009346  0.013134  0.031694       0.013015      1.000000
# price             0.006303  0.003076 -0.024097      -0.054328     -0.005377
# product_category -0.007760  0.032044  0.047757       0.000665      0.035480
#
#                      price  product_category
# gender            0.006303         -0.007760
# age               0.003076          0.032044
# country          -0.024097          0.047757
# pages_visited    -0.054328          0.000665
# session_time     -0.005377          0.035480
# price             1.000000          0.006863
# product_category  0.006863          1.000000

# %%
X['purchased'] = y

# %%
X
# Out:
#       gender  age  country  pages_visited  session_time   price  \
# 0          1   19      205              9          8.48    0.00
# 1          1   55      158             14          2.41    0.00
# 2          1   50      168             20          2.26    0.00
# 3          0   32      227             15         18.29    0.00
# 4          0   39       19              9          5.93   50.91
# ...      ...  ...      ...            ...           ...     ...
# 1995       0   38       53             17         14.95  109.09
# 1996       1   38       64              6          6.97  426.92
# 1997       1   38      108             17         29.46  118.22
# 1998       0   48      148             10         12.07  364.72
# 1999       0   46      137             10         13.62    7.81
#
#       product_category  purchased
# 0                    3          0
# 1                    2          0
# 2                    0          0
# 3                    2          0
# 4                    3          1
# ...                ...        ...
# 1995                 0          1
# 1996                 2          1
# 1997                 1          1
# 1998                 1          1
# 1999                 4          1
#
# [2000 rows x 8 columns]

# %%
y_correlate = X.corr()['purchased'].sort_values(ascending=False)

# %%
y_correlate
# Out:
# purchased           1.000000
# price               0.775887
# product_category    0.016431
# age                -0.000430
# gender             -0.012442
# country            -0.024449
# session_time       -0.030770
# pages_visited      -0.044213
# Name: purchased, dtype: float64

# %% [markdown]
# Price has a **strong positive** correlation (0.775887) with purchased:
# Inference: More expensive items are more likely to be purchased.
# Users may be engaging with high-value products, or promotions might target them.

# %% [markdown]
# Product Category has an extremely **weak positive** correlation:
# Could suggest some categories are slightly more purchased than others, but it’s marginal.

# %% [markdown]
# *****MODEL IMPLEMENTATION BELOW*****

# %%
X
# Out:
#       gender  age  country  pages_visited  session_time   price  \
# 0          1   19      205              9          8.48    0.00
# 1          1   55      158             14          2.41    0.00
# 2          1   50      168             20          2.26    0.00
# 3          0   32      227             15         18.29    0.00
# 4          0   39       19              9          5.93   50.91
# ...      ...  ...      ...            ...           ...     ...
# 1995       0   38       53             17         14.95  109.09
# 1996       1   38       64              6          6.97  426.92
# 1997       1   38      108             17         29.46  118.22
# 1998       0   48      148             10         12.07  364.72
# 1999       0   46      137             10         13.62    7.81
#
#       product_category  purchased
# 0                    3          0
# 1                    2          0
# 2                    0          0
# 3                    2          0
# 4                    3          1
# ...                ...        ...
# 1995                 0          1
# 1996                 2          1
# 1997                 1          1
# 1998                 1          1
# 1999                 4          1
#
# [2000 rows x 8 columns]

# %%
y_updated = X['purchased']

# %%
X.drop(columns='purchased',inplace=True)

# %%
X
# Out:
#       gender  age  country  pages_visited  session_time   price  \
# 0          1   19      205              9          8.48    0.00
# 1          1   55      158             14          2.41    0.00
# 2          1   50      168             20          2.26    0.00
# 3          0   32      227             15         18.29    0.00
# 4          0   39       19              9          5.93   50.91
# ...      ...  ...      ...            ...           ...     ...
# 1995       0   38       53             17         14.95  109.09
# 1996       1   38       64              6          6.97  426.92
# 1997       1   38      108             17         29.46  118.22
# 1998       0   48      148             10         12.07  364.72
# 1999       0   46      137             10         13.62    7.81
#
#       product_category
# 0                    3
# 1                    2
# 2                    0
# 3                    2
# 4                    3
# ...                ...
# 1995                 0
# 1996                 2
# 1997                 1
# 1998                 1
# 1999                 4
#
# [2000 rows x 7 columns]

# %%
y = y_updated

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# Name: purchased, Length: 2000, dtype: int64

# %%
# Train and test 
X_train = X[:1500]
y_train = y[:1500]

# %%
X_test = X[1500:]
y_test = y[1500:]

# %%
X_test.shape
# Out:
# (500, 7)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
model = RandomForestClassifier(random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[256,   0],
#        [  0, 244]])

# %%
report = classification_report(y_test, y_pred)

# %%
type(report)
# Out:
# str

# %%
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00       256\n           1       1.00      1.00      1.00       244\n\n    accuracy                           1.00       500\n   macro avg       1.00      1.00      1.00       500\nweighted avg       1.00      1.00      1.00       500\n'

# %%
report_dict = classification_report(y_test, y_pred, output_dict=True)

# %%
report_dict
# Out:
# {'0': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 256.0},
#  '1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 244.0},
#  'accuracy': 1.0,
#  'macro avg': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 500.0},
#  'weighted avg': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 500.0}}

# %%
report_df = pd.DataFrame(report_dict).transpose()
report_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_5031d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5031d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_5031d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_5031d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_5031d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5031d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5031d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5031d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_5031d_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_5031d_row0_col3" class="data row0 col3" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5031d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5031d_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_5031d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5031d_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_5031d_row1_col3" class="data row1 col3" >244.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5031d_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_5031d_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_5031d_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_5031d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5031d_row2_col3" class="data row2 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5031d_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_5031d_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_5031d_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_5031d_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_5031d_row3_col3" class="data row3 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5031d_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_5031d_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_5031d_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_5031d_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_5031d_row4_col3" class="data row4 col3" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The *classification model* achieved perfect performance metrics, including precision, recall, f1-score, and accuracy — all equal to 1.0 across both classes. This strongly suggests that the model was able to classify all instances in the test set without any errors.
#
# However, given that a synthetic dataset was used, this level of performance may not generalize well to real-world data. The synthetic nature of the dataset likely results in highly separable feature patterns that are easy for the model to learn and classify. As a result, the model may be overfitting, capturing the exact patterns of the training data instead of learning more generalizable rules.

# %% [markdown]
# *****Model Validation*****

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(model, X_test, y_test, cv=5, scoring='accuracy')

# %%
cv_scores
# Out:
# array([1., 1., 1., 1., 1.])

# %%
print("Cross-validation accuracy scores:", cv_scores)
print("Mean CV accuracy:", cv_scores.mean())
print("Standard deviation:", cv_scores.std())
# Out:
# Cross-validation accuracy scores: [1. 1. 1. 1. 1.]
# Mean CV accuracy: 1.0
# Standard deviation: 0.0

# %% [markdown]
# The model demonstrates perfect performance across all cross-validation folds, suggesting either the dataset is highly structured or the model may be overfitting to synthetic patterns. While this indicates strong model capability in capturing the dataset's structure, caution should be taken when generalizing to real-world data, which may be noisier and less predictable.

# %% [markdown]
# **Final report and conclusions on the data**

# %% [markdown]
# BEST 3 INDICATORS THAT DRIVES THE BUSINESS ARE: PRICE, PRODUCT_CATEGORY AND SESSION TIME
# - Higher or more attractive pricing seems to drive purchases.
# - Promote best-selling categories on the homepage or through ads.
# - Use personalized recommendations to highlight products from categories a user has previously browsed.
# - Streamline the user experience to reduce friction: faster checkout.
